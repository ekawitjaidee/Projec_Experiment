# %%
from keras.models import load_model,Sequential
from keras.layers import Input, Dense, LSTM,Dropout
from keras.utils import to_categorical
from keras.callbacks import Callback, ModelCheckpoint


import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

from sklearn.metrics import confusion_matrix , accuracy_score

def signal_to_catagorical(data):
  data.loc[data['Signal'] == 'wait ot hold', 'Signal'] = 'wait or hold'
  data.loc[data['Signal'] == 'buy', 'Signal'] = 0
  data.loc[data['Signal'] == 'sell', 'Signal'] = 1 
  data.loc[data['Signal'] == 'wait or hold', 'Signal'] = 1 
  return data

def add_shift_day(data,day):
  r_list = []
  for i in range(day,len(data)):#Number mean day to shift
    r_list.append(data[i-day : i])
  return np.array(r_list)

# %%
datalist = [f for f in glob.glob("../../Dataset/*.csv")]
print('have stock = ',len(datalist))
# Out:
# have stock =  75

# %%
#validation 
val_list = []
for val_name in range(71,72):
    df = pd.read_csv(datalist[val_name])
    val_x = df
    # val_x = add_shift_day(val_x,30)
    val_list.append(val_x)

#test
test_list = []
for test_name in range(72,75):
    df = pd.read_csv(datalist[test_name])
    test = df
    # test = add_shift_day(test,30)
    test_list.append(test)

# %%
model = Sequential()
model.add(LSTM(100, input_shape=((14,6)),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dense(2,activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])

checkpoint = ModelCheckpoint('Model6_checkpoint.h5',
                               verbose=1,
                               monitor='val_acc',
                               mode='max',
                               save_best_only = True)

# %%
df= pd.read_csv('train.csv')
df
# Out:
#               Date       High        Low       Open      Close    Volume  \
# 0       12/30/2002  13.061517  12.553648  12.911302  12.882689   2297300
# 1       12/31/2002  13.011445  12.725322  12.839771  12.846924   1627900
# 2         1/2/2003  13.726752  12.975679  13.032905  13.690988   3381000
# 3         1/3/2003  13.905580  13.462089  13.590844  13.626610   2622500
# 4         1/6/2003  14.384835  13.590844  13.590844  14.277539   5549500
# ...            ...        ...        ...        ...        ...       ...
# 199867   26/1/2015  22.400000  22.000000  22.100000  22.000000  14415800
# 199868   27/1/2015  22.200001  21.900000  22.200001  22.100000   6106600
# 199869   28/1/2015  22.400000  22.000000  22.299999  22.100000  10041100
# 199870   29/1/2015  22.100000  21.900000  22.000000  22.000000   6246500
# 199871   30/1/2015  22.200001  21.600000  22.100000  21.799999   9297300
#
#         Adj Close        Signal    MACD-1  SIGNAL LINE1  ...  minusDI_n  \
# 0       11.157038  wait or hold  0.364033      0.387477  ...  -0.203875
# 1       11.126063  wait or hold  0.344716      0.378925  ...  -0.233345
# 2       11.857063  wait or hold  0.392594      0.381659  ...  -0.317062
# 3       11.801311  wait or hold  0.420516      0.389430  ...  -0.355279
# 4       12.365048  wait or hold  0.489263      0.409397  ...  -0.418066
# ...           ...           ...       ...           ...  ...        ...
# 199867  18.193920  wait or hold  0.051086      0.071085  ...  -0.101863
# 199868  18.276617  wait or hold  0.053291      0.067526  ...  -0.087141
# 199869  18.276617  wait or hold  0.054412      0.064903  ...  -0.128891
# 199870  18.193920  wait or hold  0.046693      0.061261  ...  -0.101545
# 199871  18.028517  wait or hold  0.024158      0.053841  ...  -0.021536
#
#            DMI_n      %K_n      %D_n  STOCHRSI_n   Close_n      %R_n  \
# 0       0.232065  0.377839  0.438333   -0.123190 -0.714058  0.415929
# 1       0.224723  0.184685  0.311759   -0.242551 -0.716054  0.354545
# 2       0.400249  0.374540  0.343575    0.039884 -0.668930  0.963236
# 3       0.429652  0.626184  0.485539    0.236292 -0.672524  0.737374
# 4       0.521124  0.953603  0.720533    0.402181 -0.636182  0.917583
# ...          ...       ...       ...         ...       ...       ...
# 199867 -0.244507  0.437368  0.367595    0.089435  0.831409  0.111112
# 199868 -0.263767  0.434708  0.403530    0.019828  0.841399  0.222223
# 199869 -0.207052  0.432049  0.420163   -0.014976  0.841399  0.222223
# 199870 -0.230463  0.419538  0.422203   -0.041290  0.831409  0.111112
# 199871 -0.298960 -0.081294  0.171943   -0.496224  0.811427 -0.111112
#
#            RSI_n      AO_n  MA-trend_n
# 0       0.291105  0.488264   -0.284682
# 1       0.275891  0.466328   -0.280717
# 2       0.513269  0.457600   -0.396510
# 3       0.484522  0.453791   -0.389280
# 4       0.633733  0.463165   -0.476581
# ...          ...       ...         ...
# 199867 -0.035124 -0.161851    0.105173
# 199868  0.000931 -0.169310    0.059116
# 199869  0.000931 -0.154392    0.045734
# 199870 -0.041527 -0.141090    0.078408
# 199871 -0.125151 -0.142333    0.140107
#
# [199872 rows x 50 columns]

# %%
er = []
# for train_name in range(0,70):

# df = pd.read_csv(datalist[0])
df = signal_to_catagorical(df)
x_train = df[['MACD-SL-1_n','DMI_n','MACD-SL-2_n','AO_n','RSI_n','MA-trend']].values
x_train = add_shift_day(x_train,14)
y_train = df['Signal'] 
y_train = to_categorical(y_train)
y_train = y_train.tolist()
del y_train[0:14]
y_train = np.array(y_train)

r = random.randint(0,2)
val = val_list[0]
val = signal_to_catagorical(val)
x_val = val[['MACD-SL-1_n','DMI_n','MACD-SL-2_n','AO_n','RSI_n','MA-trend']].values
x_val = add_shift_day(x_val,14)
y_val = val['Signal']
y_val = to_categorical(y_val)
y_val = y_val.tolist()
del y_val[0:14]
y_val = np.array(y_val)

h = model.fit(x_train, y_train, epochs=100,validation_data=(x_val,y_val),callbacks=[checkpoint],shuffle=False)
model.save('Model6_1_100ep.h5')
plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.legend(['train', 'val'])
plt.show()
# Out:
# Epoch 1/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.2719 - acc: 0.8774
# Epoch 00001: val_acc improved from -inf to 0.84490, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 181s 29ms/step - loss: 0.2719 - acc: 0.8774 - val_loss: 0.3448 - val_acc: 0.8449
# Epoch 2/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.2638 - acc: 0.8788
# Epoch 00002: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 183s 29ms/step - loss: 0.2638 - acc: 0.8788 - val_loss: 0.3462 - val_acc: 0.8449
# Epoch 3/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.2624 - acc: 0.8789
# Epoch 00003: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 184s 30ms/step - loss: 0.2624 - acc: 0.8789 - val_loss: 0.3452 - val_acc: 0.8449
# Epoch 4/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.2616 - acc: 0.8792
# Epoch 00004: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 184s 29ms/step - loss: 0.2616 - acc: 0.8792 - val_loss: 0.3427 - val_acc: 0.8449
# Epoch 5/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2611 - acc: 0.8794
# Epoch 00005: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 184s 29ms/step - loss: 0.2611 - acc: 0.8794 - val_loss: 0.3388 - val_acc: 0.8449
# Epoch 6/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.2606 - acc: 0.8795
# Epoch 00006: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 183s 29ms/step - loss: 0.2606 - acc: 0.8795 - val_loss: 0.3383 - val_acc: 0.8449
# Epoch 7/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2600 - acc: 0.8795
# Epoch 00007: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 181s 29ms/step - loss: 0.2600 - acc: 0.8795 - val_loss: 0.3374 - val_acc: 0.8449
# Epoch 8/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.2591 - acc: 0.8796
# Epoch 00008: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 180s 29ms/step - loss: 0.2591 - acc: 0.8796 - val_loss: 0.3320 - val_acc: 0.8449
# Epoch 9/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2585 - acc: 0.8797
# Epoch 00009: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 185s 30ms/step - loss: 0.2585 - acc: 0.8797 - val_loss: 0.3305 - val_acc: 0.8449
# Epoch 10/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.2577 - acc: 0.8793
# Epoch 00010: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 184s 29ms/step - loss: 0.2577 - acc: 0.8793 - val_loss: 0.3265 - val_acc: 0.8449
# Epoch 11/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2568 - acc: 0.8792
# Epoch 00011: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 187s 30ms/step - loss: 0.2568 - acc: 0.8792 - val_loss: 0.3260 - val_acc: 0.8449
# Epoch 12/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.2560 - acc: 0.8796
# Epoch 00012: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 183s 29ms/step - loss: 0.2560 - acc: 0.8796 - val_loss: 0.3234 - val_acc: 0.8449
# Epoch 13/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2550 - acc: 0.8797- ETA: 0s - loss: 0.2550 - acc:
# Epoch 00013: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 185s 30ms/step - loss: 0.2550 - acc: 0.8797 - val_loss: 0.3228 - val_acc: 0.8449
# Epoch 14/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2541 - acc: 0.8801
# Epoch 00014: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 184s 29ms/step - loss: 0.2541 - acc: 0.8801 - val_loss: 0.3201 - val_acc: 0.8449
# Epoch 15/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.2527 - acc: 0.8804- ETA: 0s - loss: 0.2527 - acc: 0.
# Epoch 00015: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 181s 29ms/step - loss: 0.2526 - acc: 0.8805 - val_loss: 0.3199 - val_acc: 0.8449
# Epoch 16/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.2516 - acc: 0.8806
# Epoch 00016: val_acc did not improve from 0.84490
# 6246/6246 [==============================] - 174s 28ms/step - loss: 0.2516 - acc: 0.8806 - val_loss: 0.3193 - val_acc: 0.8449
# Epoch 17/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2507 - acc: 0.8814
# Epoch 00017: val_acc improved from 0.84490 to 0.84571, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 174s 28ms/step - loss: 0.2507 - acc: 0.8814 - val_loss: 0.3150 - val_acc: 0.8457
# Epoch 18/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2484 - acc: 0.8819
# Epoch 00018: val_acc did not improve from 0.84571
# 6246/6246 [==============================] - 173s 28ms/step - loss: 0.2484 - acc: 0.8820 - val_loss: 0.3154 - val_acc: 0.8453
# Epoch 19/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2473 - acc: 0.8824
# Epoch 00019: val_acc improved from 0.84571 to 0.84816, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 174s 28ms/step - loss: 0.2473 - acc: 0.8824 - val_loss: 0.3095 - val_acc: 0.8482
# Epoch 20/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.2454 - acc: 0.8833- ET
# Epoch 00020: val_acc improved from 0.84816 to 0.85633, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 173s 28ms/step - loss: 0.2454 - acc: 0.8833 - val_loss: 0.3038 - val_acc: 0.8563
# Epoch 21/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2434 - acc: 0.8836
# Epoch 00021: val_acc did not improve from 0.85633
# 6246/6246 [==============================] - 174s 28ms/step - loss: 0.2434 - acc: 0.8837 - val_loss: 0.2999 - val_acc: 0.8535
# Epoch 22/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.2415 - acc: 0.8850
# Epoch 00022: val_acc improved from 0.85633 to 0.86204, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 173s 28ms/step - loss: 0.2414 - acc: 0.8850 - val_loss: 0.3012 - val_acc: 0.8620
# Epoch 23/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2400 - acc: 0.8847
# Epoch 00023: val_acc did not improve from 0.86204
# 6246/6246 [==============================] - 173s 28ms/step - loss: 0.2400 - acc: 0.8847 - val_loss: 0.3004 - val_acc: 0.8473
# Epoch 24/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.2382 - acc: 0.8857
# Epoch 00024: val_acc did not improve from 0.86204
# 6246/6246 [==============================] - 174s 28ms/step - loss: 0.2381 - acc: 0.8858 - val_loss: 0.2988 - val_acc: 0.8502
# Epoch 25/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2360 - acc: 0.8870
# Epoch 00025: val_acc improved from 0.86204 to 0.86286, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 173s 28ms/step - loss: 0.2360 - acc: 0.8870 - val_loss: 0.2885 - val_acc: 0.8629
# Epoch 26/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.2341 - acc: 0.8882
# Epoch 00026: val_acc did not improve from 0.86286
# 6246/6246 [==============================] - 173s 28ms/step - loss: 0.2341 - acc: 0.8882 - val_loss: 0.2935 - val_acc: 0.8551
# Epoch 27/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.2320 - acc: 0.8888- ETA: 3s - loss: 0 - ETA
# Epoch 00027: val_acc did not improve from 0.86286
# 6246/6246 [==============================] - 174s 28ms/step - loss: 0.2320 - acc: 0.8888 - val_loss: 0.2886 - val_acc: 0.8608
# Epoch 28/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2294 - acc: 0.8901
# Epoch 00028: val_acc improved from 0.86286 to 0.86490, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 175s 28ms/step - loss: 0.2294 - acc: 0.8901 - val_loss: 0.2825 - val_acc: 0.8649
# Epoch 29/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2265 - acc: 0.8913
# Epoch 00029: val_acc did not improve from 0.86490
# 6246/6246 [==============================] - 173s 28ms/step - loss: 0.2265 - acc: 0.8913 - val_loss: 0.2860 - val_acc: 0.8629
# Epoch 30/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.2245 - acc: 0.8933
# Epoch 00030: val_acc did not improve from 0.86490
# 6246/6246 [==============================] - 171s 27ms/step - loss: 0.2245 - acc: 0.8933 - val_loss: 0.2898 - val_acc: 0.8571
# Epoch 31/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.2205 - acc: 0.8950
# Epoch 00031: val_acc improved from 0.86490 to 0.86980, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 172s 27ms/step - loss: 0.2205 - acc: 0.8950 - val_loss: 0.2683 - val_acc: 0.8698
# Epoch 32/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.2179 - acc: 0.8964
# Epoch 00032: val_acc did not improve from 0.86980
# 6246/6246 [==============================] - 169s 27ms/step - loss: 0.2179 - acc: 0.8964 - val_loss: 0.2726 - val_acc: 0.8641
# Epoch 33/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2166 - acc: 0.8968
# Epoch 00033: val_acc improved from 0.86980 to 0.87306, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 171s 27ms/step - loss: 0.2166 - acc: 0.8968 - val_loss: 0.2726 - val_acc: 0.8731
# Epoch 34/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.2127 - acc: 0.8986
# Epoch 00034: val_acc improved from 0.87306 to 0.87755, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 171s 27ms/step - loss: 0.2127 - acc: 0.8986 - val_loss: 0.2681 - val_acc: 0.8776
# Epoch 35/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2099 - acc: 0.9004
# Epoch 00035: val_acc did not improve from 0.87755
# 6246/6246 [==============================] - 170s 27ms/step - loss: 0.2099 - acc: 0.9004 - val_loss: 0.2567 - val_acc: 0.8722
# Epoch 36/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2070 - acc: 0.9015
# Epoch 00036: val_acc did not improve from 0.87755
# 6246/6246 [==============================] - 170s 27ms/step - loss: 0.2070 - acc: 0.9015 - val_loss: 0.2537 - val_acc: 0.8771
# Epoch 37/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.2048 - acc: 0.9024
# Epoch 00037: val_acc did not improve from 0.87755
# 6246/6246 [==============================] - 171s 27ms/step - loss: 0.2048 - acc: 0.9024 - val_loss: 0.2631 - val_acc: 0.8743
# Epoch 38/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.2022 - acc: 0.9040
# Epoch 00038: val_acc improved from 0.87755 to 0.87796, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 135s 22ms/step - loss: 0.2022 - acc: 0.9040 - val_loss: 0.2570 - val_acc: 0.8780
# Epoch 39/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.2002 - acc: 0.9050
# Epoch 00039: val_acc did not improve from 0.87796
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.2001 - acc: 0.9050 - val_loss: 0.2528 - val_acc: 0.8771
# Epoch 40/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.1985 - acc: 0.9064
# Epoch 00040: val_acc did not improve from 0.87796
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1985 - acc: 0.9064 - val_loss: 0.2515 - val_acc: 0.8747
# Epoch 41/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1944 - acc: 0.9079
# Epoch 00041: val_acc improved from 0.87796 to 0.88939, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1943 - acc: 0.9079 - val_loss: 0.2384 - val_acc: 0.8894
# Epoch 42/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1939 - acc: 0.9082
# Epoch 00042: val_acc improved from 0.88939 to 0.89184, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 119s 19ms/step - loss: 0.1938 - acc: 0.9082 - val_loss: 0.2371 - val_acc: 0.8918
# Epoch 43/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1896 - acc: 0.9099
# Epoch 00043: val_acc did not improve from 0.89184
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1896 - acc: 0.9099 - val_loss: 0.2398 - val_acc: 0.8878
# Epoch 44/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1861 - acc: 0.9113- ET
# Epoch 00044: val_acc improved from 0.89184 to 0.89510, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1861 - acc: 0.9113 - val_loss: 0.2253 - val_acc: 0.8951
# Epoch 45/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1857 - acc: 0.9116
# Epoch 00045: val_acc did not improve from 0.89510
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1857 - acc: 0.9116 - val_loss: 0.2282 - val_acc: 0.8890
# Epoch 46/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1831 - acc: 0.9134-
# Epoch 00046: val_acc improved from 0.89510 to 0.90245, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 119s 19ms/step - loss: 0.1831 - acc: 0.9134 - val_loss: 0.2227 - val_acc: 0.9024
# Epoch 47/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1791 - acc: 0.9157
# Epoch 00047: val_acc improved from 0.90245 to 0.91306, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 119s 19ms/step - loss: 0.1790 - acc: 0.9158 - val_loss: 0.2059 - val_acc: 0.9131
# Epoch 48/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1777 - acc: 0.9160- ETA: 1s - loss: 0
# Epoch 00048: val_acc did not improve from 0.91306
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1776 - acc: 0.9160 - val_loss: 0.2035 - val_acc: 0.9078
# Epoch 49/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1741 - acc: 0.9183
# Epoch 00049: val_acc did not improve from 0.91306
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1741 - acc: 0.9183 - val_loss: 0.2052 - val_acc: 0.9073
# Epoch 50/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1725 - acc: 0.919 - ETA: 0s - loss: 0.1725 - acc: 0.9193
# Epoch 00050: val_acc did not improve from 0.91306
# 6246/6246 [==============================] - 119s 19ms/step - loss: 0.1725 - acc: 0.9193 - val_loss: 0.1981 - val_acc: 0.9073
# Epoch 51/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.1707 - acc: 0.9202
# Epoch 00051: val_acc did not improve from 0.91306
# 6246/6246 [==============================] - 119s 19ms/step - loss: 0.1706 - acc: 0.9202 - val_loss: 0.2025 - val_acc: 0.9106
# Epoch 52/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1694 - acc: 0.9204
# Epoch 00052: val_acc improved from 0.91306 to 0.91796, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1694 - acc: 0.9205 - val_loss: 0.1961 - val_acc: 0.9180
# Epoch 53/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1660 - acc: 0.9229
# Epoch 00053: val_acc did not improve from 0.91796
# 6246/6246 [==============================] - 119s 19ms/step - loss: 0.1660 - acc: 0.9229 - val_loss: 0.2189 - val_acc: 0.9004
# Epoch 54/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.1642 - acc: 0.9234
# Epoch 00054: val_acc did not improve from 0.91796
# 6246/6246 [==============================] - 122s 19ms/step - loss: 0.1642 - acc: 0.9234 - val_loss: 0.1831 - val_acc: 0.9139
# Epoch 55/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.1607 - acc: 0.9250
# Epoch 00055: val_acc did not improve from 0.91796
# 6246/6246 [==============================] - 123s 20ms/step - loss: 0.1607 - acc: 0.9250 - val_loss: 0.2000 - val_acc: 0.9098
# Epoch 56/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1603 - acc: 0.9250
# Epoch 00056: val_acc did not improve from 0.91796
# 6246/6246 [==============================] - 119s 19ms/step - loss: 0.1602 - acc: 0.9250 - val_loss: 0.1892 - val_acc: 0.9163
# Epoch 57/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1578 - acc: 0.9263
# Epoch 00057: val_acc did not improve from 0.91796
# 6246/6246 [==============================] - 119s 19ms/step - loss: 0.1578 - acc: 0.9264 - val_loss: 0.1886 - val_acc: 0.9151
# Epoch 58/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.1551 - acc: 0.9280
# Epoch 00058: val_acc did not improve from 0.91796
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1551 - acc: 0.9280 - val_loss: 0.2022 - val_acc: 0.8992
# Epoch 59/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1545 - acc: 0.9283- ETA: 1s - loss: 0.
# Epoch 00059: val_acc did not improve from 0.91796
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1544 - acc: 0.9283 - val_loss: 0.2019 - val_acc: 0.8967
# Epoch 60/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1514 - acc: 0.9290
# Epoch 00060: val_acc improved from 0.91796 to 0.92041, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1514 - acc: 0.9290 - val_loss: 0.1795 - val_acc: 0.9204
# Epoch 61/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1492 - acc: 0.9307- ETA: 0s - loss: 0.1
# Epoch 00061: val_acc did not improve from 0.92041
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1491 - acc: 0.9307 - val_loss: 0.1936 - val_acc: 0.9131
# Epoch 62/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1481 - acc: 0.9318
# Epoch 00062: val_acc improved from 0.92041 to 0.92082, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1481 - acc: 0.9318 - val_loss: 0.1839 - val_acc: 0.9208
# Epoch 63/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1464 - acc: 0.9325
# Epoch 00063: val_acc did not improve from 0.92082
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1464 - acc: 0.9325 - val_loss: 0.1817 - val_acc: 0.9204
# Epoch 64/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.1435 - acc: 0.9336
# Epoch 00064: val_acc did not improve from 0.92082
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1435 - acc: 0.9336 - val_loss: 0.1944 - val_acc: 0.9163
# Epoch 65/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1435 - acc: 0.9336
# Epoch 00065: val_acc improved from 0.92082 to 0.92653, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1435 - acc: 0.9337 - val_loss: 0.1706 - val_acc: 0.9265
# Epoch 66/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1409 - acc: 0.9355
# Epoch 00066: val_acc did not improve from 0.92653
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1409 - acc: 0.9355 - val_loss: 0.1807 - val_acc: 0.9167
# Epoch 67/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.1379 - acc: 0.9367
# Epoch 00067: val_acc did not improve from 0.92653
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1379 - acc: 0.9367 - val_loss: 0.1725 - val_acc: 0.9167
# Epoch 68/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.1370 - acc: 0.9367
# Epoch 00068: val_acc did not improve from 0.92653
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1370 - acc: 0.9367 - val_loss: 0.1918 - val_acc: 0.9159
# Epoch 69/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1348 - acc: 0.9384- ETA: 0s - loss: 0.1346 - acc: 0
# Epoch 00069: val_acc did not improve from 0.92653
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1347 - acc: 0.9384 - val_loss: 0.1873 - val_acc: 0.9200
# Epoch 70/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1344 - acc: 0.9388- ETA: 0s - loss: 0.1342 - acc: 0
# Epoch 00070: val_acc did not improve from 0.92653
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1343 - acc: 0.9388 - val_loss: 0.1670 - val_acc: 0.9265
# Epoch 71/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1319 - acc: 0.9395- ETA: 1s - l
# Epoch 00071: val_acc improved from 0.92653 to 0.93837, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1319 - acc: 0.9395 - val_loss: 0.1453 - val_acc: 0.9384
# Epoch 72/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1314 - acc: 0.9397
# Epoch 00072: val_acc did not improve from 0.93837
# 6246/6246 [==============================] - 120s 19ms/step - loss: 0.1314 - acc: 0.9397 - val_loss: 0.1778 - val_acc: 0.9216
# Epoch 73/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1301 - acc: 0.9408- ETA: 0s - loss: 0.1302 - acc: 0.9
# Epoch 00073: val_acc did not improve from 0.93837
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1301 - acc: 0.9408 - val_loss: 0.1864 - val_acc: 0.9139
# Epoch 74/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1282 - acc: 0.9418
# Epoch 00074: val_acc did not improve from 0.93837
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1282 - acc: 0.9418 - val_loss: 0.1389 - val_acc: 0.9355
# Epoch 75/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1259 - acc: 0.9422
# Epoch 00075: val_acc did not improve from 0.93837
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1258 - acc: 0.9422 - val_loss: 0.1527 - val_acc: 0.9335
# Epoch 76/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1264 - acc: 0.9425
# Epoch 00076: val_acc improved from 0.93837 to 0.94612, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 119s 19ms/step - loss: 0.1263 - acc: 0.9425 - val_loss: 0.1402 - val_acc: 0.9461
# Epoch 77/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1249 - acc: 0.9441
# Epoch 00077: val_acc did not improve from 0.94612
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1248 - acc: 0.9441 - val_loss: 0.1372 - val_acc: 0.9457
# Epoch 78/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1242 - acc: 0.9443
# Epoch 00078: val_acc did not improve from 0.94612
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1242 - acc: 0.9443 - val_loss: 0.1554 - val_acc: 0.9343
# Epoch 79/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1214 - acc: 0.9455
# Epoch 00079: val_acc improved from 0.94612 to 0.95551, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1213 - acc: 0.9455 - val_loss: 0.1250 - val_acc: 0.9555
# Epoch 80/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1202 - acc: 0.9460
# Epoch 00080: val_acc did not improve from 0.95551
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1201 - acc: 0.9460 - val_loss: 0.1433 - val_acc: 0.9380
# Epoch 81/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1189 - acc: 0.9466
# Epoch 00081: val_acc did not improve from 0.95551
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1189 - acc: 0.9467 - val_loss: 0.1367 - val_acc: 0.9445
# Epoch 82/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1192 - acc: 0.9464
# Epoch 00082: val_acc did not improve from 0.95551
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1192 - acc: 0.9464 - val_loss: 0.1446 - val_acc: 0.9404
# Epoch 83/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1156 - acc: 0.9486- ETA: 2 - ETA: 0s - loss: 0.1152 - a
# Epoch 00083: val_acc did not improve from 0.95551
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1156 - acc: 0.9486 - val_loss: 0.1247 - val_acc: 0.9522
# Epoch 84/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1164 - acc: 0.9481
# Epoch 00084: val_acc did not improve from 0.95551
# 6246/6246 [==============================] - 119s 19ms/step - loss: 0.1164 - acc: 0.9481 - val_loss: 0.1460 - val_acc: 0.9404
# Epoch 85/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1155 - acc: 0.9484
# Epoch 00085: val_acc did not improve from 0.95551
# 6246/6246 [==============================] - 119s 19ms/step - loss: 0.1154 - acc: 0.9484 - val_loss: 0.1437 - val_acc: 0.9437
# Epoch 86/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1147 - acc: 0.9489
# Epoch 00086: val_acc did not improve from 0.95551
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1147 - acc: 0.9489 - val_loss: 0.1367 - val_acc: 0.9490
# Epoch 87/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1128 - acc: 0.9502- ETA:
# Epoch 00087: val_acc did not improve from 0.95551
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1128 - acc: 0.9502 - val_loss: 0.1227 - val_acc: 0.9547
# Epoch 88/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1108 - acc: 0.9511
# Epoch 00088: val_acc did not improve from 0.95551
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1108 - acc: 0.9511 - val_loss: 0.1374 - val_acc: 0.9494
# Epoch 89/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1100 - acc: 0.9515
# Epoch 00089: val_acc improved from 0.95551 to 0.96082, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 117s 19ms/step - loss: 0.1099 - acc: 0.9515 - val_loss: 0.1049 - val_acc: 0.9608
# Epoch 90/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1093 - acc: 0.9518- ETA: 0s - loss: 0.1090
# Epoch 00090: val_acc did not improve from 0.96082
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1092 - acc: 0.9518 - val_loss: 0.1091 - val_acc: 0.9580
# Epoch 91/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1082 - acc: 0.9525
# Epoch 00091: val_acc did not improve from 0.96082
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1082 - acc: 0.9525 - val_loss: 0.1419 - val_acc: 0.9429
# Epoch 92/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1076 - acc: 0.9534
# Epoch 00092: val_acc did not improve from 0.96082
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1076 - acc: 0.9534 - val_loss: 0.1068 - val_acc: 0.9514
# Epoch 93/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1084 - acc: 0.9521
# Epoch 00093: val_acc did not improve from 0.96082
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1083 - acc: 0.9521 - val_loss: 0.1091 - val_acc: 0.9576
# Epoch 94/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1062 - acc: 0.9532
# Epoch 00094: val_acc improved from 0.96082 to 0.96898, saving model to Model6_checkpoint.h5
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1062 - acc: 0.9532 - val_loss: 0.0952 - val_acc: 0.9690
# Epoch 95/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.1035 - acc: 0.9546- ETA: 0s - loss: 0.1032 - ac
# Epoch 00095: val_acc did not improve from 0.96898
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1035 - acc: 0.9546 - val_loss: 0.1015 - val_acc: 0.9571
# Epoch 96/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.1040 - acc: 0.9546
# Epoch 00096: val_acc did not improve from 0.96898
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1040 - acc: 0.9546 - val_loss: 0.1399 - val_acc: 0.9457
# Epoch 97/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.1031 - acc: 0.9554
# Epoch 00097: val_acc did not improve from 0.96898
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1031 - acc: 0.9554 - val_loss: 0.0983 - val_acc: 0.9641
# Epoch 98/100
# 6246/6246 [==============================] - ETA: 0s - loss: 0.1023 - acc: 0.9549
# Epoch 00098: val_acc did not improve from 0.96898
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.1023 - acc: 0.9549 - val_loss: 0.1033 - val_acc: 0.9608
# Epoch 99/100
# 6245/6246 [============================>.] - ETA: 0s - loss: 0.0996 - acc: 0.9564
# Epoch 00099: val_acc did not improve from 0.96898
# 6246/6246 [==============================] - 119s 19ms/step - loss: 0.0996 - acc: 0.9564 - val_loss: 0.0998 - val_acc: 0.9576
# Epoch 100/100
# 6244/6246 [============================>.] - ETA: 0s - loss: 0.0996 - acc: 0.9560
# Epoch 00100: val_acc did not improve from 0.96898
# 6246/6246 [==============================] - 118s 19ms/step - loss: 0.0996 - acc: 0.9560 - val_loss: 0.0926 - val_acc: 0.9661

# %%
model.save('Model6_1.h5')
# model = load_model('Model3_69.h5')

# %%
for test in test_list:
    # print(test)
    test = signal_to_catagorical(test)
    #   print(test)
    x_test = test[['MACD-SL-1_n','DMI_n','MACD-SL-2_n','AO_n','RSI_n','MA-trend']].values
    x_test = add_shift_day(x_test,14)
    y_test = test['Signal'].values
    y_test = y_test.tolist()
    del y_test[0:14]
    y_test = np.array(y_test)

    y_pred = model.predict(x_test)
    y_pred = np.argmax(y_pred,axis = -1)
    y_test = y_test.astype('int64')
    cm = confusion_matrix(y_test, y_pred)
    ac = accuracy_score(y_test,y_pred)
    print("Confusion Matrix")
    print(cm)
    print("Accuracy")
    print(ac)
# Out:
# Confusion Matrix
# [[ 313   39]
#  [  22 2092]]
# Accuracy
# 0.9752635847526359
# Confusion Matrix
# [[ 458   61]
#  [  87 2017]]
# Accuracy
# 0.9435760579489134
# Confusion Matrix
# [[ 423   58]
#  [  68 2119]]
# Accuracy
# 0.9527736131934033

# %%
# p_test = test_list[1]
p_test = pd.read_csv(datalist[69])
p_test = signal_to_catagorical(p_test)
x_test = p_test[['MACD-SL-1_n','DMI_n','MACD-SL-2_n','AO_n','RSI_n','MA-trend']].values
x_test = add_shift_day(x_test,14)
y_test = p_test['Signal'].values
y_test = y_test.tolist()
del y_test[0:14]
y_test = np.array(y_test)
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred,axis = -1)
p_test = p_test.iloc[14:]

p_test['pred'] = y_pred
p_test['pred_b'] = np.where(p_test['pred'] == 0,p_test['Close'],np.nan)
p_test['pred_s'] = np.where(p_test['pred'] == 1,p_test['Close'],np.nan)

plt.figure(figsize=(14,8))
# plt.grid()
plt.title('Predict Buy and Sold Signal')
plt.plot(p_test['Close'])
plt.plot(p_test['pred_b'],color='red')
plt.plot(p_test['pred_s'],color='skyblue')
plt.ylabel('Price')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
test = pd.read_csv(datalist[69])
test = signal_to_catagorical(test)
#   print(test)
x_test = test[['MACD-SL-1_n','DMI_n','MACD-SL-2_n','AO_n','RSI_n','MA-trend']].values
x_test = add_shift_day(x_test,14)
y_test = test['Signal'].values
y_test = y_test.tolist()
del y_test[0:14]
y_test = np.array(y_test)

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred,axis = -1)
y_test = y_test.astype('int64')
cm = confusion_matrix(y_test, y_pred)
ac = accuracy_score(y_test,y_pred)
print("Confusion Matrix")
print(cm)
print("Accuracy")
print(ac)
# Out:
# Confusion Matrix
# [[ 372   79]
#  [  48 2253]]
# Accuracy
# 0.9538517441860465

# %%
import pandas_datareader as web
import datetime
from Indicator import Indicator

def fillindicator(df):
    indicator = Indicator()
    train_set = indicator.MACD(df,12,26,9,1)#MACD 1
    train_set = indicator.MACD(df,40,60,34,2)#MACD 2
    train_set = indicator.DMI(df,14)
    train_set = indicator.STOCHRSI(df)
    train_set = indicator.AO(df)
    train_set = indicator.WILLIANSR(df)
    train_set = indicator.RSI(df)
    train_set = indicator.MA(df,26)
    train_set['MA-26'] = train_set['MA']
    train_set = indicator.MA(df,15)
    train_set = indicator.check_trend(df)
    return train_set

def shiftdata(df,col_name,sft):
    for i in range(sft):
        i+=1
        shiftname = col_name+'-'+str(i)
        df[shiftname] = df[col_name].shift(i)

    return df

def norm(df,col_name):# this will get columnname + _n
    #Normalize data each colunm in to range -1 to 1
    df[col_name+'_n'] = 2*(df[col_name]-df[col_name].min())/(df[col_name].max()-df[col_name].min())-1    
    return df

start = datetime.datetime(2015,10,1)#26 day before start year for make indicator
end = datetime.datetime(2020,1,1)

# %%
stock = 'true.bk'
df = web.DataReader(stock,'yahoo',start,end)
df = fillindicator(df)
df['AO-signal'] = np.where(df['AO'] > df['AO'].shift(1),1,0)
df.loc[df['Trend'] == 'Down', 'Trend'] = 0.1
df.loc[df['Trend'] == 'Up', 'Trend'] = 0.9 

#Delta
df['MACD-SL-1'] = df['MACD-1'] - df['SIGNAL LINE1']
df['MACD-SL-2'] = df['MACD-2'] - df['SIGNAL LINE2']
df['DMI'] = df['plusDI'] - df['minusDI']
df['STOCHRSI'] = df['%K'] - df['%D']
df['MA-trend'] = df['MA-26'] - df['Close']

#MACD
df = norm(df,'MACD-SL-1')
df = norm(df,'MACD-SL-2')
df = norm(df,'MACD-1')
df = norm(df,'MACD-2')
df = norm(df,'SIGNAL LINE1')
df = norm(df,'SIGNAL LINE2')

#DMI
df = norm(df,'plusDI')
df = norm(df,'minusDI')
df = norm(df,'DMI')

#StochasticRSI
df = norm(df,'%K')
df = norm(df,'%D')
df = norm(df,'STOCHRSI')

#Other
df = norm(df,'Close')
df = norm(df,'%R')
df = norm(df,'RSI')
df = norm(df,'AO')
df = norm(df,'MA-trend')
df = df[63:]
# Out:
# C:\Users\jame_\anaconda3\lib\site-packages\ta\trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# C:\Users\jame_\anaconda3\lib\site-packages\ta\trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])

# %%
p_test = df
x_test = p_test[['MACD-SL-1_n','DMI_n','MACD-SL-2_n','AO_n','RSI_n','MA-trend']].values
x_test = add_shift_day(x_test,14)
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred,axis = -1)
p_test = p_test.iloc[:]

p_test['pred'] = y_pred
p_test['pred_b'] = np.where(p_test['pred'] == 0,p_test['Close'],np.nan)
p_test['pred_s'] = np.where(p_test['pred'] == 1,p_test['Close'],np.nan)

plt.figure(figsize=(14,8))
# plt.grid()
plt.title('Predict Buy and Sold Signal')
plt.plot(p_test['Close'])
plt.plot(p_test['pred_b'],color='yellow')
plt.plot(p_test['pred_s'],color='red')
plt.ylabel('Price')
plt.xlabel('Date')
# Out:
# C:\Users\jame_\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jame_\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\jame_\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# Text(0.5, 0, 'Date')
